# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiryas1/Web-5/blob/main/WEB_Soskov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><b>Информация о сотруднике</b></h1>
# <ul>
# <li>Пол: Мужской</li>
# <li>Дата рождения: 01.01.2003</li>
# <li>ФИО: Петр Петров Петрович</li>
# <li>Должность: Менеджер по продажам</li>
# </ul>
# <h1><b>Фото сотрудника</b></h1>
#
# ![image](data:image/jpeg;base64,...)
#
#
# <h3><b>Формула</b></h3>
#
# $$y(x)=\frac{\sum_{i=1}^{n}
# \sum_{j=2}^{m} 9^2_i x_j}{\sqrt{\frac{9}{W^2}}}$$
